# %% [markdown]
# # Use mapping file created in step 1 to download meteorology data for gridpoints within basin shapefile + buffer distance

# %%
# data processing
import os
import pandas as pd, numpy as np, dask, json
import ogh
import geopandas as gpd
import ogh_xarray_landlab as oxl
import xarray as xr

# data migration library
from utilities import hydroshare

# plotting and shape libraries
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
#hs=hydroshare.hydroshare()
#homedir = hs.getContentPath(os.environ["HS_RES_ID"])
homedir = '/home/jovyan/work/notebooks/GriddedMetDataDownload/projects/TemperatureSensorRegion'
os.chdir(homedir)
print('Data will be saved to:'+homedir)
# Out:
# Data will be saved to:/home/jovyan/work/notebooks/GriddedMetDataDownload/projects/TemperatureSensorRegion

# %% [markdown]
# ##  open meta_file for use in functions below

# %%
# initialize ogh_meta
meta_file = dict(ogh.ogh_meta())
sorted(meta_file.keys())
# Out:
# ['dailymet_bclivneh2013',
#  'dailymet_livneh2013',
#  'dailymet_livneh2015',
#  'dailyvic_livneh2013',
#  'dailyvic_livneh2015',
#  'dailywrf_bcsalathe2014',
#  'dailywrf_salathe2014',
#  'hourlywrf_pnnl']

# %%
#check characteristics of data
meta_file['dailywrf_salathe2014']['start_date']
# Out:
# '1950-01-01'

# %% [markdown]
# ## Re-establish the paths to the mapping file

# %%
# map the mapping files generated for Sauk-Suiattle, Elwha, and Upper Rio Salado from usecase1
mappingfile_PNNL = os.path.join(homedir,'Puyallup_P_mappingfile_i.csv')

mappingfile_VIC = os.path.join(homedir, 'Puyallup_VIC_mappingfile.csv') 

t1 = ogh.mappingfileSummary(listofmappingfiles = [mappingfile_PNNL,mappingfile_VIC], 
                            listofwatershednames = ['Puyallup_PNNL','Puyallup_VIC'],
                            meta_file=meta_file)

t1
# Out:
# Watershed                                                            Puyallup_PNNL  \
# Median elevation in meters [range](Number of gridded cells)  1613[997-1857] (n=34)
# dailymet_bclivneh2013                                                            0
# dailymet_livneh2013                                                              0
# dailymet_livneh2015                                                              0
# dailyvic_livneh2013                                                              0
# dailyvic_livneh2015                                                              0
# dailywrf_bcsalathe2014                                                           0
# dailywrf_salathe2014                                                             0
# hourlywrf_pnnl                                               1613[997-1857] (n=34)
#
# Watershed                                                             Puyallup_VIC
# Median elevation in meters [range](Number of gridded cells)  1603[866-1958] (n=37)
# dailymet_bclivneh2013                                        1603[866-1958] (n=37)
# dailymet_livneh2013                                          1603[866-1958] (n=37)
# dailymet_livneh2015                                          1603[866-1958] (n=37)
# dailyvic_livneh2013                                          1603[866-1958] (n=37)
# dailyvic_livneh2015                                          1603[866-1958] (n=37)
# dailywrf_bcsalathe2014                                       1623[866-1958] (n=34)
# dailywrf_salathe2014                                         1623[866-1958] (n=34)
# hourlywrf_pnnl                                                                   0

# %% [markdown]
# ### convert mapping file to dataframe: maptable

# %%
maptable_p, nstations_p = ogh.mappingfileToDF_PNNL(mappingfile_PNNL)
maptable_p
nstations_p
# Out:
# Number of gridded data files:34
# Minimum elevation: 997.522521973m
# Mean elevation: 1518.119246539206m
# Maximum elevation: 1857.13256836m
# 34

# %%
maptable_v, nstations_v = ogh.mappingfileToDF(mappingfile_VIC)
maptable_v
nstations_v
# Out:
# Number of gridded data files:34
# Minimum elevation: 866.0m
# Mean elevation: 1541.0882352941176m
# Maximum elevation: 1958.0m
# 34

# %%
maptable_p
maptable_v
# Out:
#     FID       LAT      LONG_    ELEV  \
# 0     0  48.71875 -120.90625  1369.0
# 1     1  48.71875 -120.96875  1168.0
# 2     2  48.71875 -121.03125  1139.0
# 3     3  48.71875 -121.09375   867.0
# 4     4  48.71875 -121.15625   866.0
# 6     6  48.65625 -120.53125  1193.0
# 7     7  48.65625 -120.59375  1425.0
# 8     8  48.65625 -120.78125  1845.0
# 9     9  48.65625 -120.84375  1421.0
# 10   10  48.65625 -120.90625  1626.0
# 11   11  48.65625 -120.96875  1569.0
# 12   12  48.65625 -121.03125  1176.0
# 13   13  48.65625 -121.09375  1150.0
# 14   14  48.65625 -121.15625  1807.0
# 17   17  48.59375 -120.53125  1457.0
# 18   18  48.59375 -120.59375  1621.0
# 19   19  48.59375 -120.65625  1758.0
# 20   20  48.59375 -120.71875  1898.0
# 21   21  48.59375 -120.78125  1603.0
# 22   22  48.59375 -120.84375  1634.0
# 23   23  48.59375 -120.90625  1743.0
# 24   24  48.59375 -120.96875  1626.0
# 25   25  48.59375 -121.03125  1093.0
# 26   26  48.53125 -120.53125  1862.0
# 27   27  48.53125 -120.59375  1958.0
# 28   28  48.53125 -120.65625  1742.0
# 29   29  48.53125 -120.71875  1805.0
# 30   30  48.53125 -120.78125  1682.0
# 31   31  48.53125 -120.84375  1864.0
# 32   32  48.53125 -120.90625  1690.0
# 33   33  48.46875 -120.59375  1761.0
# 34   34  48.46875 -120.65625  1874.0
# 35   35  48.46875 -120.71875  1596.0
# 36   36  48.46875 -120.78125  1509.0
#
#                                   dailymet_livneh2013  \
# 0   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 1   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 2   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 3   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 4   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 6   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 7   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 8   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 9   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 10  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 11  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 12  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 13  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 14  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 17  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 18  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 19  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 20  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 21  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 22  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 23  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 24  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 25  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 26  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 27  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 28  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 29  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 30  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 31  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 32  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 33  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 34  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 35  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 36  /home/jovyan/work/notebooks/GriddedMetDataDown...
#
#                                 dailymet_bclivneh2013  \
# 0   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 1   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 2   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 3   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 4   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 6   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 7   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 8   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 9   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 10  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 11  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 12  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 13  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 14  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 17  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 18  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 19  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 20  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 21  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 22  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 23  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 24  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 25  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 26  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 27  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 28  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 29  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 30  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 31  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 32  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 33  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 34  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 35  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 36  /home/jovyan/work/notebooks/GriddedMetDataDown...
#
#                                   dailymet_livneh2015  \
# 0   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 1   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 2   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 3   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 4   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 6   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 7   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 8   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 9   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 10  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 11  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 12  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 13  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 14  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 17  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 18  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 19  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 20  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 21  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 22  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 23  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 24  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 25  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 26  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 27  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 28  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 29  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 30  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 31  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 32  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 33  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 34  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 35  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 36  /home/jovyan/work/notebooks/GriddedMetDataDown...
#
#                                   dailyvic_livneh2013  \
# 0   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 1   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 2   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 3   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 4   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 6   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 7   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 8   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 9   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 10  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 11  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 12  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 13  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 14  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 17  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 18  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 19  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 20  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 21  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 22  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 23  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 24  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 25  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 26  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 27  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 28  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 29  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 30  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 31  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 32  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 33  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 34  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 35  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 36  /home/jovyan/work/notebooks/GriddedMetDataDown...
#
#                                   dailyvic_livneh2015  \
# 0   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 1   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 2   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 3   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 4   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 6   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 7   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 8   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 9   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 10  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 11  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 12  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 13  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 14  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 17  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 18  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 19  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 20  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 21  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 22  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 23  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 24  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 25  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 26  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 27  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 28  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 29  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 30  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 31  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 32  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 33  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 34  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 35  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 36  /home/jovyan/work/notebooks/GriddedMetDataDown...
#
#                                  dailywrf_salathe2014  \
# 0   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 1   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 2   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 3   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 4   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 6   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 7   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 8   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 9   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 10  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 11  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 12  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 13  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 14  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 17  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 18  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 19  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 20  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 21  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 22  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 23  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 24  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 25  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 26  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 27  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 28  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 29  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 30  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 31  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 32  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 33  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 34  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 35  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 36  /home/jovyan/work/notebooks/GriddedMetDataDown...
#
#                                dailywrf_bcsalathe2014
# 0   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 1   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 2   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 3   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 4   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 6   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 7   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 8   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 9   /home/jovyan/work/notebooks/GriddedMetDataDown...
# 10  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 11  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 12  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 13  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 14  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 17  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 18  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 19  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 20  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 21  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 22  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 23  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 24  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 25  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 26  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 27  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 28  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 29  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 30  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 31  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 32  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 33  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 34  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 35  /home/jovyan/work/notebooks/GriddedMetDataDown...
# 36  /home/jovyan/work/notebooks/GriddedMetDataDown...

# %% [markdown]
# ## Download grid points in mapping file from of PNNL 2018 netCDF files, convert to ascii
# #### becuase of memore problem with dataset.to_dataframe(), use chunks: 1981to1987, 1988 to 1994, 1995 to 2001, 2002 to 2008,  2009 to 2015

# %%
#chunks = [('1981-01-01','1987-12-31'),('1988-01-01','1994-12-31'),('1995-01-01','2001-12-31'),('2002-01-01','2008-12-31'),('2009-01-01','2015-12-31')]
chunks = [('2001-01-01','2005-12-31'),('2006-01-01','2010-12-31'),('2011-01-01','2015-12-31')]

# %%
type(chunks)
chunks
# Out:
# [('2001-01-01', '2005-12-31'),
#  ('2006-01-01', '2010-12-31'),
#  ('2011-01-01', '2015-12-31')]

# %% [markdown]
# ### Define grid cells to be clipped from NetCDF files

# %%
spatialbounds = {'minx':maptable_p.WE.min().astype(np.int64), 'maxx':maptable_p.WE.max().astype(np.int64),
                 'miny':maptable_p.SN.min().astype(np.int64), 'maxy':maptable_p.SN.max().astype(np.int64)}
spatialbounds
# Out:
# {'minx': 56, 'maxx': 65, 'miny': 57, 'maxy': 62}

# %% [markdown]
# #### check directory that data will be saved to

# %%
datadir = homedir
datadir

# %%
# %%time
for chunk in chunks:

    #update datadir to save downloaded data in appropriate location
    #use get_x_hourlywrf_PNNL2018_dir if only directory needed
    outputfiles = oxl.get_x_hourlywrf_PNNL2018(homedir=datadir,
                                                spatialbounds=spatialbounds,
                                                subdir='PNNL/' + chunk[0] + 'to' + chunk[1] +'/',
                                                nworkers=40,
                                                start_date=chunk[0],
                                                end_date=chunk[1],
                                                file_prefix='sp_',
                                                replace_file=True)


    outputlist = oxl.netcdf_to_ascii_PNNL2018(homedir=homedir,
                                 subdir='PNNL/ASCII/' + chunk[0] + 'to' + chunk[1] +'/',
                                 netcdfs=outputfiles,
                                 mappingfile=mappingfile_PNNL,
                                 catalog_label='hourlywrf_pnnl',
                                 meta_file=meta_file)
                                 #time_nm = '20060101to20101231')
# Out:
# [                                        ] | 0% Completed |  3.5scropped
# cropped
# cropped
# [                                        ] | 0% Completed |  3.7scropped
# cropped
# cropped
# cropped
# [                                        ] | 0% Completed |  3.8scropped
# cropped
# cropped
# cropped
# [                                        ] | 0% Completed |  4.1scropped
# [                                        ] | 0% Completed |  4.2scropped
# cropped
# cropped
# [                                        ] | 0% Completed |  5.6sdownloaded: spatial subset of data.2004-11-04.nc
# downloaded: spatial subset of data.2001-10-13.nc
# downloaded: spatial subset of data.2004-07-04.nc
# downloaded: spatial subset of data.2003-07-25.nc
# [                                        ] | 0% Completed |  5.9sdownloaded: spatial subset of data.2003-10-04.nc
# downloaded: spatial subset of data.2004-02-25.nc
# downloaded: spatial subset of data.2005-11-08.nc
# downloaded: spatial subset of data.2001-06-08.nc
# [                                        ] | 0% Completed |  6.1sdownloaded: spatial subset of data.2005-07-04.nc
# downloaded: spatial subset of data.2001-04-01.nc
# downloaded: spatial subset of data.2001-04-07.nc
# downloaded: spatial subset of data.2001-03-07.nc
# [                                        ] | 0% Completed |  6.2sdownloaded: spatial subset of data.2002-05-09.ncdownloaded: spatial subset of data.2001-10-03.nc
#
# [                                        ] | 0% Completed |  6.3sdownloaded: spatial subset of data.2004-11-25.nc
# [                                        ] | 0% Completed |  7.9scropped
# cropped
# cropped
# [                                        ] | 0% Completed |  8.0scropped
# cropped
# [                                        ] | 0% Completed |  8.2scropped
# [                                        ] | 0% Completed |  8.3scropped
# [                                        ] | 0% Completed |  8.4scropped
# cropped
# [                                        ] | 0% Completed |  8.6scropped
# [                                        ] | 0% Completed |  9.7sdownloaded: spatial subset of data.2001-03-30.nc
# [                                        ] | 0% Completed |  9.9sdownloaded: spatial subset of data.2001-12-23.nc
# downloaded: spatial subset of data.2004-10-28.nc
# [                                        ] | 0% Completed | 10.3sdownloaded: spatial subset of data.2005-10-17.nc
# downloaded: spatial subset of data.2003-05-26.nc
# downloaded: spatial subset of data.2003-02-15.nc
# downloaded: spatial subset of data.2005-07-06.nc
# [                                        ] | 1% Completed | 10.5sdownloaded: spatial subset of data.2001-02-10.nc
# downloaded: spatial subset of data.2003-02-02.nc
# [                                        ] | 1% Completed | 10.7sdownloaded: spatial subset of data.2001-07-25.nc
# [                                        ] | 1% Completed | 10.9scropped
# [                                        ] | 1% Completed | 11.2scropped
# [                                        ] | 1% Completed | 11.3scropped
# [                                        ] | 1% Completed | 11.6scropped
# cropped
# [                                        ] | 1% Completed | 11.7scropped
# [                                        ] | 1% Completed | 12.2scropped
# [                                        ] | 1% Completed | 12.4scropped
# [                                        ] | 1% Completed | 12.6scropped
# [                                        ] | 1% Completed | 12.8scropped
# cropped
# [                                        ] | 1% Completed | 13.4scropped
# downloaded: spatial subset of data.2002-08-24.nc
# cropped
# [                                        ] | 1% Completed | 13.5scropped
# cropped
# [                                        ] | 1% Completed | 13.7sdownloaded: spatial subset of data.2004-04-22.nc
# [                                        ] | 1% Completed | 14.0scropped
# cropped
# cropped
# [                                        ] | 1% Completed | 14.2sdownloaded: spatial subset of data.2002-08-10.nc
# [                                        ] | 1% Completed | 14.3scropped
# downloaded: spatial subset of data.2002-07-04.nc
# downloaded: spatial subset of data.2002-12-23.nc
# cropped
# cropped
# [                                        ] | 1% Completed | 14.5sdownloaded: spatial subset of data.2003-01-13.nc
# cropped
# [                                        ] | 1% Completed | 14.8scropped
# cropped
# downloaded: spatial subset of data.2002-05-10.nc
# [                                        ] | 1% Completed | 15.1scropped
# cropped
# downloaded: spatial subset of data.2002-04-21.nc
# cropped
# [                                        ] | 1% Completed | 15.4scropped
# [                                        ] | 1% Completed | 15.5sdownloaded: spatial subset of data.2002-02-08.nc
# downloaded: spatial subset of data.2002-05-30.nc
# downloaded: spatial subset of data.2003-08-28.nc
# cropped
# [                                        ] | 1% Completed | 16.0scropped
# downloaded: spatial subset of data.2003-04-24.nc
# downloaded: spatial subset of data.2004-05-30.nc
# downloaded: spatial subset of data.2002-04-29.nc
# [                                        ] | 2% Completed | 16.2sdownloaded: spatial subset of data.2003-02-06.nc
# cropped
# downloaded: spatial subset of data.2001-05-26.nc
# downloaded: spatial subset of data.2003-09-03.nc
# [                                        ] | 2% Completed | 16.5sdownloaded: spatial subset of data.2005-02-22.nc
# cropped
# [                                        ] | 2% Completed | 16.8s
# downloaded: spatial subset of data.2004-12-04.nc
# downloaded: spatial subset of data.2003-06-04.nc
# downloaded: spatial subset of data.2001-02-17.nc
# downloaded: spatial subset of data.2003-11-28.nc
# cropped
# cropped
# downloaded: spatial subset of data.2005-11-03.nc
# cropped
# downloaded: spatial subset of data.2001-04-27.nc
# downloaded: spatial subset of data.2002-12-08.nc
# downloaded: spatial subset of data.2001-12-06.nc
# downloaded: spatial subset of data.2004-06-16.nc
# cropped
# downloaded: spatial subset of data.2003-04-29.nc
# cropped
# cropped
# croppeddownloaded: spatial subset of data.2001-05-02.nc
# cropped
#
# downloaded: spatial subset of data.2005-11-04.nc
# downloaded: spatial subset of data.2001-03-17.nc
# downloaded: spatial subset of data.2002-03-14.nc
# downloaded: spatial subset of data.2004-10-01.nc
# downloaded: spatial subset of data.2002-12-04.nc
# downloaded: spatial subset of data.2003-06-20.nc
# cropped
# downloaded: spatial subset of data.2004-09-10.nc
# cropped
# downloaded: spatial subset of data.2003-10-24.nc
# cropped
# downloaded: spatial subset of data.2003-12-11.nc
# downloaded: spatial subset of data.2004-07-03.nc
# downloaded: spatial subset of data.2004-03-28.nc
# cropped
# cropped
# cropped
# cropped
# cropped
# cropped
# cropped
# cropped
# cropped
# cropped
# downloaded: spatial subset of data.2002-08-18.nc
# downloaded: spatial subset of data.2001-04-19.nc
# downloaded: spatial subset of data.2002-05-20.nc
# cropped
# cropped
# cropped
# cropped
# cropped
# downloaded: spatial subset of data.2005-09-28.nc
# downloaded: spatial subset of data.2002-04-23.nc
# downloaded: spatial subset of data.2001-12-28.nc
# downloaded: spatial subset of data.2001-07-07.nc
# downloaded: spatial subset of data.2004-01-22.nc
# downloaded: spatial subset of data.2002-03-03.nc
# downloaded: spatial subset of data.2003-11-03.nc
# downloaded: spatial subset of data.2003-03-19.nc
# downloaded: spatial subset of data.2003-12-24.nc
# downloaded: spatial subset of data.2002-05-01.nc
# downloaded: spatial subset of data.2005-11-19.nc
# downloaded: spatial subset of data.2004-01-05.nc
# downloaded: spatial subset of data.2005-11-10.nc
# downloaded: spatial subset of data.2002-12-13.nc
# downloaded: spatial subset of data.2001-04-13.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/github/keckje/ogh_xarray_landlab.py in get_x_hourlywrf_PNNL2018(homedir, spatialbounds, subdir, nworkers, start_date, end_date, time_resolution, time_steps, file_prefix, rename_timelatlong_names, replace_file)
#     395
#     396     # run operations
# --> 397     outputfiles = da.compute(NetCDFs)[0]
#     398
#     399     # reset working directory
#
# /opt/conda/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     405     keys = [x.__dask_keys__() for x in collections]
#     406     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 407     results = get(dsk, keys, **kwargs)
#     408     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     409
#
# /opt/conda/lib/python3.6/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, **kwargs)
#      73     results = get_async(pool.apply_async, len(pool._pool), dsk, result,
#      74                         cache=cache, get_id=_thread_get_id,
# ---> 75                         pack_exception=pack_exception, **kwargs)
#      76
#      77     # Cleanup pools associated to dead threads
#
# /opt/conda/lib/python3.6/site-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     510             # Main loop, wait on tasks to finish, insert new ones
#     511             while state['waiting'] or state['ready'] or state['running']:
# --> 512                 key, res_info, failed = queue_get(queue)
#     513                 if failed:
#     514                     exc, tb = loads(res_info)
#
# /opt/conda/lib/python3.6/site-packages/dask/local.py in queue_get(q)
#     149 else:
#     150     def queue_get(q):
# --> 151         return q.get()
#     152
#     153
#
# /opt/conda/lib/python3.6/queue.py in get(self, block, timeout)
#     162             elif timeout is None:
#     163                 while not self._qsize():
# --> 164                     self.not_empty.wait()
#     165             elif timeout < 0:
#     166                 raise ValueError("'timeout' must be a non-negative number")
#
# /opt/conda/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Download Salathe and Livneh ascii files that corrispond to gridpoints in mappingfile

# %%
# %%time

ogh.getDailyMET_livneh2013(homedir, mappingfile_VIC)
ogh.getDailyMET_bcLivneh2013(homedir, mappingfile_VIC)
ogh.getDailyMET_livneh2015(homedir, mappingfile_VIC)
ogh.getDailyVIC_livneh2013(homedir, mappingfile_VIC)
ogh.getDailyVIC_livneh2015(homedir, mappingfile_VIC)
ogh.getDailyWRF_salathe2014(homedir, mappingfile_VIC)
ogh.getDailyWRF_bcsalathe2014(homedir, mappingfile_VIC)

# %% [markdown]
# ### Update mapping file summary

# %%
t1 = ogh.mappingfileSummary(listofmappingfiles = [mappingfile_PNNL,mappingfile_VIC], 
                            listofwatershednames = ['Puyallup_PNNL','Puyallup_VIC'],
                            meta_file=meta_file)

t1
#t1.to_csv(os.path.join(homedir, 'watershed_table.txt'), sep='\t', header=True, index=True)
# Out:
# Watershed                                                            Puyallup_PNNL  \
# Median elevation in meters [range](Number of gridded cells)  1613[997-1857] (n=34)
# dailymet_bclivneh2013                                                            0
# dailymet_livneh2013                                                              0
# dailymet_livneh2015                                                              0
# dailyvic_livneh2013                                                              0
# dailyvic_livneh2015                                                              0
# dailywrf_bcsalathe2014                                                           0
# dailywrf_salathe2014                                                             0
# hourlywrf_pnnl                                               1613[997-1857] (n=34)
#
# Watershed                                                             Puyallup_VIC
# Median elevation in meters [range](Number of gridded cells)  1603[866-1958] (n=37)
# dailymet_bclivneh2013                                        1603[866-1958] (n=37)
# dailymet_livneh2013                                          1603[866-1958] (n=37)
# dailymet_livneh2015                                          1603[866-1958] (n=37)
# dailyvic_livneh2013                                          1603[866-1958] (n=37)
# dailyvic_livneh2015                                          1603[866-1958] (n=37)
# dailywrf_bcsalathe2014                                       1623[866-1958] (n=34)
# dailywrf_salathe2014                                         1623[866-1958] (n=34)
# hourlywrf_pnnl                                                                   0

# %% [markdown]
# ## Combine and summarize individual ascii files into a dictionary: ltm

# %% [markdown]
# #### Livneh 2013

# %%
# Livneh et al., 2013
dr1 = meta_file['dailymet_livneh2013']

# Salathe et al., 2014
dr2 = meta_file['dailywrf_salathe2014']

# define overlapping time window
dr = ogh.overlappingDates(date_set1=tuple([dr1['start_date'], dr1['end_date']]), 
                          date_set2=tuple([dr2['start_date'], dr2['end_date']]))
dr
# Out:
# ('1950-01-01', '2010-12-31')

# %%
# %%time
ltm = ogh.gridclim_dict(mappingfile=mappingfile_VIC,
                        metadata=meta_file,
                        dataset='dailymet_livneh2013',
                        subset_start_date='1915-01-01',
                        subset_end_date='2011-12-31')

# compute sums and mean monthly an yearly sums
ltm = ogh.aggregate_space_time_sum(df_dict=ltm,
                                   suffix='PRECIP_dailymet_livneh2013',
                                   start_date=dr[0],
                                   end_date=dr[1])
# Out:
# DatetimeIndex(['1915-01-01', '1915-01-02', '1915-01-03', '1915-01-04',
#                '1915-01-05', '1915-01-06', '1915-01-07', '1915-01-08',
#                '1915-01-09', '1915-01-10',
#                ...
#                '2011-12-22', '2011-12-23', '2011-12-24', '2011-12-25',
#                '2011-12-26', '2011-12-27', '2011-12-28', '2011-12-29',
#                '2011-12-30', '2011-12-31'],
#               dtype='datetime64[ns]', length=35429, freq='D')
# DatetimeIndex(['1915-01-01', '1915-01-02', '1915-01-03', '1915-01-04',
#                '1915-01-05', '1915-01-06', '1915-01-07', '1915-01-08',
#                '1915-01-09', '1915-01-10',
#                ...
#                '2011-12-22', '2011-12-23', '2011-12-24', '2011-12-25',
#                '2011-12-26', '2011-12-27', '2011-12-28', '2011-12-29',
#                '2011-12-30', '2011-12-31'],
#               dtype='datetime64[ns]', length=35429, freq='D')
# Number of data files within elevation range (866.0-1958.0 m): 37
# [########################################] | 100% Completed |  0.6s
# PRECIP dataframe reading complete:0:00:00.701410
# [########################################] | 100% Completed |  0.5s
# TMAX dataframe reading complete:0:00:01.279490
# [########################################] | 100% Completed |  0.5s
# TMIN dataframe reading complete:0:00:01.866150
# [########################################] | 100% Completed |  0.6s
# WINDSPD dataframe reading complete:0:00:02.491357
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# PRECIP_dailymet_livneh2013 calculations completed in 0:00:00.336341
# CPU times: user 5.39 s, sys: 499 ms, total: 5.89 s
# Wall time: 2.84 s

# %% [markdown]
# #### Salathe 2014

# %%
# %%time
ltm = ogh.gridclim_dict(mappingfile=mappingfile_VIC,
                        metadata=meta_file,
                        dataset='dailywrf_salathe2014',
                        subset_start_date='1915-01-01',
                        subset_end_date='2011-12-31',
                        df_dict = ltm)

# compute sums and mean monthly an yearly sums
ltm = ogh.aggregate_space_time_sum(df_dict=ltm,
                                   suffix='PRECIP_dailywrf_salathe2014',
                                   start_date='1950-01-01',
                                   end_date='2010-12-31')
# Out:
# DatetimeIndex(['1950-01-01', '1950-01-02', '1950-01-03', '1950-01-04',
#                '1950-01-05', '1950-01-06', '1950-01-07', '1950-01-08',
#                '1950-01-09', '1950-01-10',
#                ...
#                '2010-12-22', '2010-12-23', '2010-12-24', '2010-12-25',
#                '2010-12-26', '2010-12-27', '2010-12-28', '2010-12-29',
#                '2010-12-30', '2010-12-31'],
#               dtype='datetime64[ns]', length=22280, freq='D')
# DatetimeIndex(['1915-01-01', '1915-01-02', '1915-01-03', '1915-01-04',
#                '1915-01-05', '1915-01-06', '1915-01-07', '1915-01-08',
#                '1915-01-09', '1915-01-10',
#                ...
#                '2011-12-22', '2011-12-23', '2011-12-24', '2011-12-25',
#                '2011-12-26', '2011-12-27', '2011-12-28', '2011-12-29',
#                '2011-12-30', '2011-12-31'],
#               dtype='datetime64[ns]', length=35429, freq='D')
# Number of data files within elevation range (866.0-1958.0 m): 34
# PRECIP dataframe reading complete:0:00:00.498150
# TMAX dataframe reading complete:0:00:00.969937
# TMIN dataframe reading complete:0:00:01.483202
# WINDSPD dataframe reading complete:0:00:01.948551
# PRECIP_dailywrf_salathe2014 calculations completed in 0:00:00.162724
# CPU times: user 3.37 s, sys: 376 ms, total: 3.75 s
# Wall time: 2.16 s

# %%
#check data sets stored in ltm dictionary
ltm.keys()
# Out:
# dict_keys(['PRECIP_dailymet_livneh2013', 'TMAX_dailymet_livneh2013', 'TMIN_dailymet_livneh2013', 'WINDSPD_dailymet_livneh2013', 'meanalldailysum_PRECIP_dailymet_livneh2013', 'monthsum_PRECIP_dailymet_livneh2013', 'meanbymonthsum_PRECIP_dailymet_livneh2013', 'meanmonthsum_PRECIP_dailymet_livneh2013', 'meanallmonthsum_PRECIP_dailymet_livneh2013', 'yearsum_PRECIP_dailymet_livneh2013', 'meanbyyearsum_PRECIP_dailymet_livneh2013', 'meanyearsum_PRECIP_dailymet_livneh2013', 'meanallyearsum_PRECIP_dailymet_livneh2013'])

# %% [markdown]
# #### PNNL 2018

# %% [markdown]
# ### combine chunks then add to ltm dictionary

# %% [markdown]
# #### chunks used to download data:

# %%
#chunks = [('2001-01-01','2005-12-31')]
chunks = [('2001-01-01','2005-12-31'),('2006-01-01','2010-12-31'),('2011-01-01','2015-12-31')]
type(chunks)
# Out:
# list

# %% [markdown]
# #### Create dictionary Ldict: each chunk has a key in dictionary. Within each key are all of the variables from the PNNL dataset

# %%
# %%time
Ldict ={}
for ind, chunk in enumerate(chunks):
    
    homedir = '/home/jovyan/work/notebooks/GriddedMetDataDownload/projects/TemperatureSensorRegion/PNNL/ASCII/'+ chunk[0] + 'to' + chunk[1] +'/'
    os.chdir(homedir)

    # %%time
    file_start_date = chunk[0]
    file_end_date = chunk[1] + ' 23:00:00'
    subset_start_date = file_start_date
    subset_end_date =file_end_date
    #change time step in metafile to hourly
    Ldict[ind] = ogh.gridclim_dict(mappingfile=mappingfile_PNNL,
                            metadata=meta_file,
                            dataset='hourlywrf_pnnl',
                            file_start_date = file_start_date,
                            file_end_date = file_end_date,
                            subset_start_date=subset_start_date,
                            subset_end_date=subset_end_date)
# Out:
# CPU times: user 9 µs, sys: 4 µs, total: 13 µs
# Wall time: 26 µs
# DatetimeIndex(['2001-01-01 00:00:00', '2001-01-01 01:00:00',
#                '2001-01-01 02:00:00', '2001-01-01 03:00:00',
#                '2001-01-01 04:00:00', '2001-01-01 05:00:00',
#                '2001-01-01 06:00:00', '2001-01-01 07:00:00',
#                '2001-01-01 08:00:00', '2001-01-01 09:00:00',
#                ...
#                '2005-12-31 14:00:00', '2005-12-31 15:00:00',
#                '2005-12-31 16:00:00', '2005-12-31 17:00:00',
#                '2005-12-31 18:00:00', '2005-12-31 19:00:00',
#                '2005-12-31 20:00:00', '2005-12-31 21:00:00',
#                '2005-12-31 22:00:00', '2005-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=43824, freq='H')
# DatetimeIndex(['2001-01-01 00:00:00', '2001-01-01 01:00:00',
#                '2001-01-01 02:00:00', '2001-01-01 03:00:00',
#                '2001-01-01 04:00:00', '2001-01-01 05:00:00',
#                '2001-01-01 06:00:00', '2001-01-01 07:00:00',
#                '2001-01-01 08:00:00', '2001-01-01 09:00:00',
#                ...
#                '2005-12-31 14:00:00', '2005-12-31 15:00:00',
#                '2005-12-31 16:00:00', '2005-12-31 17:00:00',
#                '2005-12-31 18:00:00', '2005-12-31 19:00:00',
#                '2005-12-31 20:00:00', '2005-12-31 21:00:00',
#                '2005-12-31 22:00:00', '2005-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=43824, freq='H')
# Number of data files within elevation range (997.522521973-1857.13256836 m): 34
# [########################################] | 100% Completed |  0.7s
# T2 dataframe reading complete:0:00:00.819264
# [########################################] | 100% Completed |  0.7s
# Q2 dataframe reading complete:0:00:01.640897
# [########################################] | 100% Completed |  0.6s
# PSFC dataframe reading complete:0:00:02.356903
# [########################################] | 100% Completed |  0.6s
# GLW dataframe reading complete:0:00:03.046338
# [########################################] | 100% Completed |  0.7s
# SWDOWN dataframe reading complete:0:00:03.806913
# [########################################] | 100% Completed |  0.8s
# U10 dataframe reading complete:0:00:04.652942
# [########################################] | 100% Completed |  0.8s
# V10 dataframe reading complete:0:00:05.475206
# [########################################] | 100% Completed |  0.6s
# PREC_ACC_NC dataframe reading complete:0:00:06.166515
# [########################################] | 100% Completed |  0.7s
# SNOW_ACC_NC dataframe reading complete:0:00:06.910972
# CPU times: user 10 µs, sys: 5 µs, total: 15 µs
# Wall time: 29.3 µs
# DatetimeIndex(['2006-01-01 00:00:00', '2006-01-01 01:00:00',
#                '2006-01-01 02:00:00', '2006-01-01 03:00:00',
#                '2006-01-01 04:00:00', '2006-01-01 05:00:00',
#                '2006-01-01 06:00:00', '2006-01-01 07:00:00',
#                '2006-01-01 08:00:00', '2006-01-01 09:00:00',
#                ...
#                '2010-12-31 14:00:00', '2010-12-31 15:00:00',
#                '2010-12-31 16:00:00', '2010-12-31 17:00:00',
#                '2010-12-31 18:00:00', '2010-12-31 19:00:00',
#                '2010-12-31 20:00:00', '2010-12-31 21:00:00',
#                '2010-12-31 22:00:00', '2010-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=43824, freq='H')
# DatetimeIndex(['2006-01-01 00:00:00', '2006-01-01 01:00:00',
#                '2006-01-01 02:00:00', '2006-01-01 03:00:00',
#                '2006-01-01 04:00:00', '2006-01-01 05:00:00',
#                '2006-01-01 06:00:00', '2006-01-01 07:00:00',
#                '2006-01-01 08:00:00', '2006-01-01 09:00:00',
#                ...
#                '2010-12-31 14:00:00', '2010-12-31 15:00:00',
#                '2010-12-31 16:00:00', '2010-12-31 17:00:00',
#                '2010-12-31 18:00:00', '2010-12-31 19:00:00',
#                '2010-12-31 20:00:00', '2010-12-31 21:00:00',
#                '2010-12-31 22:00:00', '2010-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=43824, freq='H')
# Number of data files within elevation range (997.522521973-1857.13256836 m): 34
# [########################################] | 100% Completed |  0.7s
# T2 dataframe reading complete:0:00:00.795460
# [########################################] | 100% Completed |  0.7s
# Q2 dataframe reading complete:0:00:01.578945
# [########################################] | 100% Completed |  0.7s
# PSFC dataframe reading complete:0:00:02.371321
# [########################################] | 100% Completed |  0.7s
# GLW dataframe reading complete:0:00:03.117520
# [########################################] | 100% Completed |  0.7s
# SWDOWN dataframe reading complete:0:00:03.866227
# [########################################] | 100% Completed |  0.7s
# U10 dataframe reading complete:0:00:04.601903
# [########################################] | 100% Completed |  0.6s
# V10 dataframe reading complete:0:00:05.295427
# [########################################] | 100% Completed |  0.8s
# PREC_ACC_NC dataframe reading complete:0:00:06.136242
# [########################################] | 100% Completed |  0.7s
# SNOW_ACC_NC dataframe reading complete:0:00:06.877979
# CPU times: user 10 µs, sys: 4 µs, total: 14 µs
# Wall time: 28.4 µs
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00',
#                ...
#                '2015-12-31 14:00:00', '2015-12-31 15:00:00',
#                '2015-12-31 16:00:00', '2015-12-31 17:00:00',
#                '2015-12-31 18:00:00', '2015-12-31 19:00:00',
#                '2015-12-31 20:00:00', '2015-12-31 21:00:00',
#                '2015-12-31 22:00:00', '2015-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=43824, freq='H')
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00',
#                ...
#                '2015-12-31 14:00:00', '2015-12-31 15:00:00',
#                '2015-12-31 16:00:00', '2015-12-31 17:00:00',
#                '2015-12-31 18:00:00', '2015-12-31 19:00:00',
#                '2015-12-31 20:00:00', '2015-12-31 21:00:00',
#                '2015-12-31 22:00:00', '2015-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=43824, freq='H')
# Number of data files within elevation range (997.522521973-1857.13256836 m): 34
# [########################################] | 100% Completed |  0.8s
# T2 dataframe reading complete:0:00:00.869050
# [########################################] | 100% Completed |  0.7s
# Q2 dataframe reading complete:0:00:01.656773
# [########################################] | 100% Completed |  0.7s
# PSFC dataframe reading complete:0:00:02.461517
# [########################################] | 100% Completed |  0.8s
# GLW dataframe reading complete:0:00:03.280823
# [########################################] | 100% Completed |  0.7s
# SWDOWN dataframe reading complete:0:00:04.000850
# [########################################] | 100% Completed |  0.8s
# U10 dataframe reading complete:0:00:04.833790
# [########################################] | 100% Completed |  0.7s
# V10 dataframe reading complete:0:00:05.600597
# [########################################] | 100% Completed |  0.7s
# PREC_ACC_NC dataframe reading complete:0:00:06.365966
# [########################################] | 100% Completed |  0.7s
# SNOW_ACC_NC dataframe reading complete:0:00:07.090997
# CPU times: user 1min 37s, sys: 44.9 s, total: 2min 22s
# Wall time: 20.9 s

# %%
#look how variables are orgainzed in dataframes stored in dictionary ltm:

dty = (list(Ldict[0].keys())) #variables in PNNL data
Ldict_c = Ldict #copy of dictionary of variables, Ldict is mutable
#Ldict[0]['T2_hourlywrf_pnnl'].head()
dty
Ldict.keys()
# Out:
# dict_keys([0, 1, 2])

# %% [markdown]
# ### for each variable, concatenate each chunks into a single time series, add timeseries to ltm dictionary

# %%
frames = {}
dd = {}
for var in dty:
    for k, v in Ldict.items():
          df = Ldict_c[k][var]
          mi = df.columns
          indi = pd.Index([e[0] for e in mi.tolist()])
          df.columns = indi
          #df
          frames[str(k)+var] = df  
          if k == 0:
            ltm[var] = df
          else:
            ltm[var] = ltm[var].append(df)

# %%
#method above removes multi comlumn index of PNNL dataset, add back in next notebook
ltm.keys()
ltm['T2_hourlywrf_pnnl'].head()
# Out:
#                              0           1           2           3   \
# 2001-01-01 00:00:00  258.968842  257.480957  257.024109  257.332916
# 2001-01-01 01:00:00  257.610596  256.783783  256.267578  256.333069
# 2001-01-01 02:00:00  257.697937  256.820923  256.686951  256.480499
# 2001-01-01 03:00:00  258.277618  257.619690  257.541046  256.899384
# 2001-01-01 04:00:00  259.038757  258.291260  258.213654  257.435303
#
#                              4           5           6           7   \
# 2001-01-01 00:00:00  257.186951  256.994232  257.122345  256.548798
# 2001-01-01 01:00:00  255.972015  256.531555  256.684021  255.693100
# 2001-01-01 02:00:00  256.308044  256.845825  257.072906  256.352600
# 2001-01-01 03:00:00  257.212433  257.345795  257.977600  257.429840
# 2001-01-01 04:00:00  257.771271  257.940918  258.652954  258.070953
#
#                              8           9      ...              24  \
# 2001-01-01 00:00:00  256.765167  259.218933     ...      258.732544
# 2001-01-01 01:00:00  256.127441  258.555573     ...      257.785858
# 2001-01-01 02:00:00  256.636810  258.639984     ...      258.131805
# 2001-01-01 03:00:00  257.699493  258.895660     ...      259.067535
# 2001-01-01 04:00:00  258.366028  259.480438     ...      260.090027
#
#                              25          26          27          28  \
# 2001-01-01 00:00:00  262.778839  262.704529  262.498352  260.840118
# 2001-01-01 01:00:00  261.228821  261.932343  261.582275  259.781372
# 2001-01-01 02:00:00  261.004333  261.815338  261.516541  259.681488
# 2001-01-01 03:00:00  261.582916  261.665497  261.267975  260.024323
# 2001-01-01 04:00:00  261.740967  260.350769  261.039764  260.401398
#
#                              29          30          31          32  \
# 2001-01-01 00:00:00  259.134674  262.999786  262.952209  262.628998
# 2001-01-01 01:00:00  258.151733  260.942932  261.281281  261.533508
# 2001-01-01 02:00:00  258.091431  260.703766  260.973816  261.435913
# 2001-01-01 03:00:00  258.441132  261.837097  261.093903  261.329834
# 2001-01-01 04:00:00  258.985596  261.730499  260.903259  261.289886
#
#                              33
# 2001-01-01 00:00:00  260.948090
# 2001-01-01 01:00:00  259.824066
# 2001-01-01 02:00:00  259.849487
# 2001-01-01 03:00:00  260.080566
# 2001-01-01 04:00:00  260.392975
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Save ltm dictionary to a pickle file that can be easily opened in same form next notebook

# %%
homedir = '/home/jovyan/work/notebooks/GriddedMetDataDownload/projects/TemperatureSensorRegion'
os.chdir(homedir)

# %%
pwd
# Out:
# '/home/jovyan/work/notebooks/GriddedMetDataDownload/projects/TemperatureSensorRegion'

# %%
import pickle #use pick file to retain dictionary file structure
f = open("TempSensorArea_2001to2015.pkl","wb") #write binary
pickle.dump(ltm,f)
f.close() #pickle files must be closed

# %%
import pickle #use pick file to retain dictionary file structure
f = open("TempSensorArea_2001to2015_SepartePereods.pkl","wb") #write binary
pickle.dump(Ldict,f)
f.close() #pickle files must be closed

# %% [markdown]
# ### Define wateryear summary functions

# %%
def WaterYear_Accum(df):
    
    """
    #df = S_PNNL_1981to1987['PREC_ACC_NC_hourlywrf_pnnl'] or any other dataframe in dictionary created by grid_clim_dict
    
    """
    #step 1, add water year (WY) column to data
    aa = df.index.to_series() #convert index to series so that lambda function can be applied 
    df['WY'] = aa.apply(lambda x: x.year if x.month < 10 else x.year+1)
    
    #step 2, remove datetime index to column, label column
    df_re = df.rename_axis('Date').reset_index()
    
    #step 3, move WY as index
    df_re.set_index('WY', inplace=True)
    
    #step 4, sum values in each column (grid point) by WY
    WYs_Sta = df_re.groupby(df_re.index).sum()
    
    #step 5, take mean of each grid cell as basin value
    WYs_basin = WYs_Sta.mean(axis=1)
    
    return(WYs_basin)


def WaterYear_Mean(df):
    
    """
    #df = S_PNNL_1981to1987['PREC_ACC_NC_hourlywrf_pnnl'] or any other dataframe in dictionary created by grid_clim_dict
    
    """
    #step 1, add water year (WY) column to data
    aa = df.index.to_series() #convert index to series so that lambda function can be applied 
    df['WY'] = aa.apply(lambda x: x.year if x.month < 10 else x.year+1)
    
    #step 2, remove datetime index to column, label column
    df_re = df.rename_axis('Date').reset_index()
    
    #step 3, move WY as index
    df_re.set_index('WY', inplace=True)
    
    #step 4, average values in each column (grid point) by WY
    WYm_Sta = df_re.groupby(df_re.index).mean()
    
    #step 5, take mean of each grid cell as basin value
    WYm_basin = WYm_Sta.mean(axis=1)
    
    return(WYm_basin)

# %%
PNNL_hp = ltm['PREC_ACC_NC_hourlywrf_pnnl']
#water year accumulated precip
WYp = WaterYear_Accum(PNNL_hp)
#water year mean temp
PNNL_hT = ltm['T2_hourlywrf_pnnl']
WYt = WaterYear_Mean(PNNL_hT)
#water year mean solar radiation W/m2
PNNL_hRs = ltm['SWDOWN_hourlywrf_pnnl']
WYs = WaterYear_Mean(PNNL_hRs)

# %%
WYp
type(WYt)
# Out:
# pandas.core.series.Series
